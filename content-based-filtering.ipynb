# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Read Files

# %%
# Read games.csv
game_details = pd.read_csv('final_data/game_details_subset.csv')
game_details.drop(['date_release', 'price', 'image_url', 'web_url', 'rating'], axis='columns', inplace=True)
game_details.set_index('app_id', inplace=True)
print(game_details.head())
# Out:
#                                     name  \
# app_id
# 440                      Team Fortress 2
# 550                        Left 4 Dead 2
# 570                               Dota 2
# 620                             Portal 2
# 730     Counter-Strike: Global Offensive
#
#                                               description  \
# app_id
# 440     The most fun you can have online - PC Gamer Is...
# 550     Set in the zombie apocalypse, Left 4 Dead 2 (L...
# 570     The most-played game on Steam. Every day, mill...
# 620     Portal 2 draws from the award-winning formula ...
# 730     Counter-Strike: Global Offensive (CS: GO) expa...
#
#                                                 languages  platform_windows  \
# app_id
# 440     ['English', 'Danish', 'Dutch', 'Finnish', 'Fre...              True
# 550     ['Danish', 'Dutch', 'English', 'Finnish', 'Fre...              True
# 570     ['Bulgarian', 'Czech', 'Danish', 'Dutch', 'Eng...              True
# 620     ['English', 'French', 'German', 'Spanish - Spa...              True
# 730     ['Czech', 'Danish', 'Dutch', 'English', 'Finni...              True
#
#         platform_mac  platform_linux                       developers  \
# app_id
# 440             True            True                            Valve
# 550             True            True                            Valve
# 570             True            True                            Valve
# 620             True            True                            Valve
# 730             True            True  Valve,Hidden Path Entertainment
#
#                                                categories  \
# app_id
# 440     multiplayer,crossplatformmultiplayer,steamachi...
# 550     singleplayer,multiplayer,pvp,onlinepvp,coop,on...
# 570     multiplayer,coop,steamtradingcards,steamworksh...
# 620     singleplayer,multiplayer,coop,onlinecoop,share...
# 730     multiplayer,steamachievements,fullcontrollersu...
#
#                             genres
# app_id
# 440              action,freetoplay
# 550                         action
# 570     action,freetoplay,strategy
# 620               action,adventure
# 730              action,freetoplay

# %%
# Split dataset for separate processing
name_df = game_details.loc[:,['name']]                  #map
desc_df = game_details.loc[:,['description']]           #tdidf
lang_df = game_details.loc[:,['languages']]             #ohe
plat_df = game_details.loc[:,['platform_windows',
                              'platform_mac',
                              'platform_linux']]        #ohe
dev_df = game_details.loc[:,['developers']]             #ohe
cat_df = game_details.loc[:,['categories']]             #ohe
genres_df = game_details.loc[:,['genres']]              #ohe
genres_df.head()
# Out:
#                             genres
# app_id
# 440              action,freetoplay
# 550                         action
# 570     action,freetoplay,strategy
# 620               action,adventure
# 730              action,freetoplay

# %%
# Genre - One Hot Encoding (by CountVectorizer)
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
feature_vectors = vectorizer.fit_transform(genres_df['genres']).toarray()
vocab = vectorizer.get_feature_names_out()
genres_ohe = pd.DataFrame(data = feature_vectors, index = genres_df.index, columns = vocab)
genres_ohe.head(10)
# Out:
#          action  adventure  animationmodeling  casual  designillustration  \
# app_id
# 440           1          0                  0       0                   0
# 550           1          0                  0       0                   0
# 570           1          0                  0       0                   0
# 620           1          1                  0       0                   0
# 730           1          0                  0       0                   0
# 4000          0          0                  0       0                   0
# 945360             0           0      0                     0             0
# 1063730            0           0      0                     1             0
# 1085660            0           1      0                     0             0
# 1091500            0           0      0                     0             0
# 1097150            0           0      1                     1             0
# 1172470            0           1      0                     0             0
# 1172620            0           0      0                     0             0
# 1174180            0           0      0                     0             0
# 1245620            0           0      0                     0             0
#
#          racing  rpg  simulation  sports  strategy  utilities
# app_id
# 440           0    0           0       0         0          0
# 550           0    0           0       0         0          0
# 570           0    0           0       0         1          0
# 620           0    0           0       0         0          0
# 730           0    0           0       0         0          0
# 4000          0    0           1       0         0          0
# 49520         0    1           0       0         0          0
# 72850         0    1           0       0         0          0
# 105600        0    1           0       0         0          0
# 107410        0    0           1       0         1          0
# 218620        0    1           0       0         0          0
# 221100        0    0           0       0         0          0
# 227300        0    0           1       0         0          0
# 230410        0    1           0       0         0          0
# 236390        0    0           1       0         0          0
# 239140        0    1           0       0         0          0
# 242760        0    0           1       0         0          0
# 251570        0    1           1       0         1          0
# 252490        0    1           0       0         0          0
# 252950        1    0           0       1         0          0
# 271590        0    0           0       0         0          0
# 275850        0    0           0       0         0          0
# 289070        0    0           0       0         1          0
# 291550        0    0           0       0         0          0
# 292030        0    1           0       0         0          0
# 304930        0    0           0       0         0          0
# 322330        0    0           1       0         0          0
# 346110        0    1           0       0         0          0
# 359550        0    0           0       0         0          0
# 367520        0    0           0       0         0          0
# 374320        0    0           0       0         0          0
# 377160        0    1           0       0         0          0
# 381210        0    0           0       0         0          0
# 413150        0    1           1       0         0          0
# 431960        0    0           0       0         0          1
# 444090        0    0           0       0         0          0
# 489830        0    1           0       0         0          0
# 578080        0    0           0       0         0          0
# 582010        0    0           0       0         0          0
# 739630        0    0           0       0         0          0
# 892970        0    1           0       0         0          0
# 945360        0    0           0       0         0          0
# 1063730       0    1           0       0         0          0
# 1085660       0    0           0       0         0          0
# 1091500       0    1           0       0         0          0
# 1097150       0    0           0       1         0          0
# 1172470       0    0           0       0         0          0
# 1172620       0    0           0       0         0          0
# 1174180       0    0           0       0         0          0
# 1245620       0    1           0       0         0          0

# %%
# Perform Cosine Similarity Matrix
from sklearn.metrics.pairwise import cosine_similarity
cs_matrix = pd.DataFrame(cosine_similarity(genres_ohe), index=genres_ohe.index, columns=genres_ohe.index)
cs_matrix.head(10)

# Save to File
cs_matrix.to_csv('final_data/content-based-similarity-matrix.csv', index=True)

# %%
# Given App_Id, Find Most Similar Games (by Genres)
def get_similar_list(query_app_id, index_start, index_end):
    query_app_id = str(query_app_id)
    cs_matrix = pd.read_csv('final_data/content-based-similarity-matrix.csv')
    result = cs_matrix.loc[:,['app_id', query_app_id]].sort_values(by=query_app_id,ascending=False)
    return result['app_id'][index_start:index_end].values

query_app_id = 550
final = get_similar_list(query_app_id, 0, 10)
final
# Out:
# array([ 582010,  381210,  374320,  359550,     550,     440,  239140,
#        1174180, 1172620,  444090], dtype=int64)
